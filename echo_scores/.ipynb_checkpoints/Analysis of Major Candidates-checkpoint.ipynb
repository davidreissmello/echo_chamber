# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
candidate_info = pd.read_csv('Candidates_2018.txt', sep='\t')
raw = pd.read_csv('echo_computation3.csv', low_memory=False)
opponents = pd.read_csv('opponents.csv')

# %%
raw['ratio'] = raw.f_of_f_candidate_followers/raw.n_f_of_f
raw['ratio_normalized'] = raw.ratio/raw.n_candidate_followers
raw['ratio_normalized_log'] = raw.ratio/np.log(raw.n_candidate_followers)
#divide by number of followers + opponent followers 
#divide by log(number of candidate followers)

#raw['ratio_normalized'] = raw.ratio/ state followers


raw['only_candidate'] = raw.f_of_f_candidate_followers - raw.candidate_and_opponent_followers
raw['only_opponent'] = raw.opponent_followers - raw.candidate_and_opponent_followers

raw['ratio_only_candidate'] = raw.only_candidate / raw.n_f_of_f
raw['ratio_only_candidate_normalized'] = raw.ratio_only_candidate / raw.n_candidate_followers

raw['ratio_only_opponent'] = raw.only_opponent / raw.n_f_of_f
raw['ratio_only_opponent_normalized'] = raw.ratio_only_opponent / raw.n_candidate_followers

raw['ratio_candidate_and_opponent'] = raw.candidate_and_opponent_followers / raw.n_f_of_f
raw['ratio_candidate_and_opponent_normalized'] = raw.ratio_candidate_and_opponent / raw.n_candidate_followers

raw['ratio_opponent_over_candidate_followers'] = raw.opponent_followers / raw.n_f_of_f
# Out:
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df = pd.merge(raw, candidate_info, left_on='candidates', right_on='UserID')

# %%
def opponent_followers(candidate_id):
    try:
        opp = opponents[opponents['republican_id'] == candidate_id].democrat_id.tolist() \
                + opponents[opponents['democrat_id'] == candidate_id].republican_id.tolist()

        if len(opp) != 0:
            opp = opp[0]
            opp_followers = raw[raw['candidates'] == opp].n_candidate_followers.values[0]
            can_followers = raw[raw['candidates'] == candidate_id].n_candidate_followers.values[0]

            return opp_followers + can_followers

        return 0 
    except:
        return 0

# %%
raw['n_can_opp_followers'] = raw.candidates.apply(opponent_followers)

# %%
raw['ratio_normalized_can_opp'] = raw.ratio/raw.n_can_opp_followers

# %% [markdown]
# # Most/Least Echo Chambered Candidates

# %%
import json
with open('major_candidates.txt', 'r') as filehandle:
    major_candidates = json.load(filehandle)

# %%
candidate_echo = raw.groupby('candidates').mean()
states = pd.read_csv('states.csv')
candidate_echo = pd.merge(candidate_echo, states, left_on='Real Name', right_on='candidate')
candidate_echo = pd.merge(candidate_echo, candidate_info, left_index = True, right_on='UserID')
candidate_echo = candidate_echo[candidate_echo['Real Name'].isin(major_candidates)]

# %%
candidate_echo['ratio_normalized_state'] = candidate_echo.ratio / candidate_echo.population_2018

# %%
#THE CURRENT BOB FLANDERS ACCOUNT IS NOT THE REAL ONE, SO TAKING HIS NAME OUT
candidate_echo = candidate_echo[candidate_echo['Real Name'] != 'Bob Flanders']

# %%
#Remove Candidates with very few number of followers 
candidate_echo = candidate_echo[candidate_echo.n_candidate_followers > 10000]

# %%
target = "ratio_normalized"
most_echod_candidate = candidate_echo.nlargest(20, target).sort_values(target, ascending=True)
plt.barh(most_echod_candidate['Real Name'], most_echod_candidate[target])
plt.title('Most Echo Chambered Candidates')
plt.show()

least_echod_candidate = candidate_echo.nsmallest(20, target).sort_values(target, ascending=False)
plt.barh(least_echod_candidate['Real Name'], least_echod_candidate[target])
plt.title('Least Echo Chambered Candidates')
plt.show()

# %%
target = "ratio_normalized_log"
most_echod_candidate = candidate_echo.nlargest(20, target).sort_values(target, ascending=True)
plt.barh(most_echod_candidate['Real Name'], most_echod_candidate[target])
plt.title('Most Echo Chambered Candidates')
plt.show()

least_echod_candidate = candidate_echo.nsmallest(20, target).sort_values(target, ascending=False)
plt.barh(least_echod_candidate['Real Name'], least_echod_candidate[target])
plt.title('Least Echo Chambered Candidates')
plt.show()

# %%
target = "ratio_normalized_state"
most_echod_candidate = candidate_echo.nlargest(20, target).sort_values(target, ascending=True)
plt.barh(most_echod_candidate['Real Name'], most_echod_candidate[target])
plt.title('Most Echo Chambered Candidates')
plt.show()

least_echod_candidate = candidate_echo.nsmallest(20, target).sort_values(target, ascending=False)
plt.barh(least_echod_candidate['Real Name'], least_echod_candidate[target])
plt.title('Least Echo Chambered Candidates')
plt.show()

# %% [markdown]
# # Distribution of Echo Chamberedness for Candidates

# %%
plt.hist(candidate_echo.ratio_normalized*1000000, bins=50)
plt.title('Echo Chamberedness of Candidates')
plt.show()

# %%
plt.hist(candidate_echo.ratio_normalized_log*1000000, bins=50)
plt.title('Echo Chamberedness of Candidates')
plt.show()

# %%
plt.hist(candidate_echo.ratio_normalized_state*1000000, bins=50)
plt.title('Echo Chamberedness of Candidates')
plt.show()

# %% [markdown]
# # How does number of followers correlate with echo chamberedness?

# %%
#remove small candidates and recompute graphs

# %%
plt.scatter(candidate_echo.n_candidate_followers, candidate_echo.ratio_normalized)
plt.title('Number of Followers vs Echo Chamberedness of Candidates')
plt.ylim(-0.000001, 0.000005)
plt.show()
np.corrcoef(candidate_echo.n_candidate_followers, candidate_echo.ratio_normalized)
# Out:
# array([[ 1.        , -0.40867213],
#        [-0.40867213,  1.        ]])

# %%
plt.scatter(candidate_echo.n_candidate_followers, candidate_echo.ratio_normalized_log)
plt.title('Number of Followers vs Echo Chamberedness of Candidates')
plt.show()
np.corrcoef(candidate_echo.n_candidate_followers, candidate_echo.ratio_normalized_log)
# Out:
# array([[1.        , 0.34867673],
#        [0.34867673, 1.        ]])

# %%
plt.scatter(candidate_echo.n_candidate_followers, candidate_echo.ratio_normalized_state)
plt.title('Number of Followers vs Echo Chamberedness of Candidates')
plt.show()
np.corrcoef(candidate_echo.n_candidate_followers, candidate_echo.ratio_normalized_state)
# Out:
# array([[ 1.        , -0.07816587],
#        [-0.07816587,  1.        ]])

# %% [markdown]
# # POLLS

# %%
#polls = pd.read_csv('../poll_variance/poll_variances_2018.csv')

# %%
from fuzzywuzzy import fuzz

def match_name(name, list_names, min_score=0):
    # -1 score incase we don't get any matches
    max_score = -1
    # Returning empty name for no match as well
    max_name = ""
    # Iternating over all names in the other
    for name2 in list_names:
        #Finding fuzzy match score
        score = fuzz.ratio(name, name2)
        # Checking if we are above our threshold and have a better score
        if (score > min_score) & (score > max_score):
            max_name = name2
            max_score = score
    return (max_name, max_score)

# %%
# List for dicts for easy dataframe creation
dict_list = []
# iterating over our players without salaries found above
for name in candidate_echo['Real Name']:
    # Use our method to find best match, we can set a threshold here
    match = match_name(name, polls.candidate_name)
    
    # New dict for storing data
    dict_ = {}
    dict_.update({"twitter_name" : name})
    dict_.update({"poll_name" : match[0]})
    dict_.update({"score" : match[1]})
    dict_list.append(dict_)
    
merge_table = pd.DataFrame(dict_list)
# Display results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-294-ad308fc634de> in <module>
#       4 for name in candidate_echo['Real Name']:
#       5     # Use our method to find best match, we can set a threshold here
# ----> 6     match = match_name(name, polls.candidate_name)
#       7
#       8     # New dict for storing data
#
# NameError: name 'polls' is not defined

# %%
polls = pd.merge(polls, merge_table, left_on='candidate_name', right_on='poll_name')
polls.to_csv('polls_twitter_names.csv', index=False)

# %%
polls_new = pd.read_csv('polls_twitter_names_clean.csv')

# %%
poll_analysis = pd.merge(candidate_echo, polls_new, left_on='Real Name', right_on='twitter_name')

# %%
poll_analysis = poll_analysis[poll_analysis.poll_variance.isnull() == False]

# %%
plt.scatter(poll_analysis.poll_variance, poll_analysis.ratio_normalized)
plt.title('Poll Variance (538 Data) vs Normalized Echo Chamber')
plt.show()
np.corrcoef(poll_analysis.poll_variance, poll_analysis.ratio_normalized)
# Out:
# array([[1.        , 0.10767896],
#        [0.10767896, 1.        ]])

# %%
plt.scatter(poll_analysis.poll_variance, poll_analysis.ratio_normalized_log)
plt.title('Poll Variance (538 Data) vs Normalized Echo Chamber')
plt.show()
np.corrcoef(poll_analysis.poll_variance, poll_analysis.ratio_normalized_log)
# Out:
# array([[ 1.        , -0.23873998],
#        [-0.23873998,  1.        ]])

# %%
plt.scatter(poll_analysis.poll_variance, poll_analysis.ratio_normalized_state)
plt.title('Poll Variance (538 Data) vs Normalized Echo Chamber')
plt.show()
np.corrcoef(poll_analysis.poll_variance, poll_analysis.ratio_normalized_state)
# Out:
# array([[ 1.        , -0.02560436],
#        [-0.02560436,  1.        ]])

# %%
poll_analysis.corr()['poll_variance'].sort_values()
# Out:
# ratio_normalized_can_opp                  -0.360019
# score                                     -0.355209
# ratio_only_candidate                      -0.288212
# followers                                 -0.251266
# ratio                                     -0.244003
# ratio_normalized_log                      -0.238740
# n_candidate_followers                     -0.158124
# Followers Count                           -0.158118
# Statuses Count                            -0.118489
# ratio_normalized_state                    -0.025604
# ratio_only_candidate_normalized           -0.010278
# ratio_candidate_and_opponent_normalized   -0.010278
# UserID                                    -0.002983
# only_candidate                             0.018963
# ratio_only_opponent_normalized             0.038981
# f_of_f_candidate_followers                 0.063203
# ratio_normalized                           0.107679
# Friends Count                              0.117460
# ratio_only_opponent                        0.152102
# n_can_opp_followers                        0.172814
# ratio_opponent_over_candidate_followers    0.183153
# only_opponent                              0.197694
# ratio_candidate_and_opponent               0.208659
# opponent_followers                         0.213005
# n_f_of_f                                   0.217597
# candidate_and_opponent_followers           0.259325
# population_2018                            0.316406
# Favourites Count                           0.380595
# poll_variance                              1.000000
# Name: poll_variance, dtype: float64

# %%
X_original = poll_analysis[list(poll_analysis.corr().columns)].drop(columns=['poll_variance', 'ratio_normalized_can_opp'])
y = poll_analysis.poll_variance

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X_original)
X = pd.DataFrame(X, columns=X_original.columns, index = X_original.index)
# Out:
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
import statsmodels.api as sm
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          poll_variance   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                 -1.098
# Method:                 Least Squares   F-statistic:                    0.1673
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):               1.00
# Time:                        15:42:16   Log-Likelihood:                -154.60
# No. Observations:                  35   AIC:                             353.2
# Df Residuals:                      13   BIC:                             387.4
# Df Model:                          22
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# followers                                  -1.2990     11.456     -0.113      0.911     -26.048      23.450
# f_of_f_candidate_followers                  1.2660      5.724      0.221      0.828     -11.099      13.631
# n_f_of_f                                   -1.3656     21.399     -0.064      0.950     -47.595      44.864
# ratio                                      -7.6593     51.391     -0.149      0.884    -118.682     103.364
# n_candidate_followers                   -5.408e+04    8.9e+04     -0.608      0.554   -2.46e+05    1.38e+05
# ratio_normalized                            0.5648     35.582      0.016      0.988     -76.305      77.435
# opponent_followers                         -3.8355     20.000     -0.192      0.851     -47.042      39.371
# candidate_and_opponent_followers           -5.1769     54.668     -0.095      0.926    -123.281     112.927
# ratio_normalized_log                        9.7682     79.332      0.123      0.904    -161.617     181.154
# only_candidate                              2.2359     11.533      0.194      0.849     -22.680      27.152
# only_opponent                              -3.4609     24.433     -0.142      0.890     -56.245      49.323
# ratio_only_candidate                       -7.9303     46.593     -0.170      0.867    -108.589      92.728
# ratio_only_candidate_normalized            -4.3124     16.141     -0.267      0.794     -39.183      30.558
# ratio_only_opponent                        -1.6755     32.317     -0.052      0.959     -71.492      68.141
# ratio_only_opponent_normalized              9.5966     43.969      0.218      0.831     -85.393     104.586
# ratio_candidate_and_opponent                1.9180     47.826      0.040      0.969    -101.403     105.239
# ratio_candidate_and_opponent_normalized    -4.3124     16.141     -0.267      0.794     -39.183      30.558
# ratio_opponent_over_candidate_followers    -0.5506     18.459     -0.030      0.977     -40.429      39.327
# n_can_opp_followers                         4.3874     15.664      0.280      0.784     -29.454      38.228
# UserID                                     -1.4721      7.512     -0.196      0.848     -17.700      14.756
# Favourites Count                            8.3269     23.345      0.357      0.727     -42.106      58.760
# Friends Count                              -0.1343     10.383     -0.013      0.990     -22.566      22.297
# Followers Count                          5.408e+04    8.9e+04      0.608      0.554   -1.38e+05    2.46e+05
# Statuses Count                             -2.8857     15.120     -0.191      0.852     -35.550      29.779
# population_2018                             8.1534     14.807      0.551      0.591     -23.835      40.142
# ratio_normalized_state                      4.4776      8.855      0.506      0.622     -14.652      23.607
# score                                      -5.4993      7.126     -0.772      0.454     -20.893       9.895
# ==============================================================================
# Omnibus:                        5.057   Durbin-Watson:                   0.322
# Prob(Omnibus):                  0.080   Jarque-Bera (JB):                3.744
# Skew:                           0.540   Prob(JB):                        0.154
# Kurtosis:                       4.184   Cond. No.                     1.41e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.62e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
results.params.sort_values()
# Out:
# n_candidate_followers                     -54084.465241
# ratio_only_candidate                          -7.930318
# ratio                                         -7.659272
# score                                         -5.499288
# candidate_and_opponent_followers              -5.176945
# ratio_only_candidate_normalized               -4.312444
# ratio_candidate_and_opponent_normalized       -4.312444
# opponent_followers                            -3.835469
# only_opponent                                 -3.460938
# Statuses Count                                -2.885657
# ratio_only_opponent                           -1.675525
# UserID                                        -1.472150
# n_f_of_f                                      -1.365602
# followers                                     -1.298992
# ratio_opponent_over_candidate_followers       -0.550639
# Friends Count                                 -0.134269
# ratio_normalized                               0.564846
# f_of_f_candidate_followers                     1.266019
# ratio_candidate_and_opponent                   1.917966
# only_candidate                                 2.235874
# n_can_opp_followers                            4.387429
# ratio_normalized_state                         4.477554
# population_2018                                8.153414
# Favourites Count                               8.326940
# ratio_only_opponent_normalized                 9.596584
# ratio_normalized_log                           9.768198
# Followers Count                            54084.577522
# dtype: float64

# %% [markdown]
# # VOTER TURNOUT

# %% [markdown]
# figure out the state for each twitter account

# %%
election_results = pd.read_csv('election_results.csv')

# %%
dem_candidates = election_results.candidate_18_dem.dropna()
rep_candidates = election_results.candidate_18_rep.dropna()

# %%
#match democrats, then republicans
# List for dicts for easy dataframe creation
dict_list = []
# iterating over our players without salaries found above
#for name in rep_candidates:
for name in dem_candidates:
    # Use our method to find best match, we can set a threshold here
    match = match_name(name, candidate_echo['Real Name'])

    # New dict for storing data
    dict_ = {}
    dict_.update({"twitter_name" : name})
    dict_.update({"dem_name" : match[0]})
    dict_.update({"score" : match[1]})
    dict_list.append(dict_)


merge_table = pd.DataFrame(dict_list)
# Display results
#merge_table.to_csv('rep_candidates_fuzzy.csv', index=False)
merge_table.to_csv('dem_candidates_fuzzy1.csv', index=False)

# %%
rep_candidates_fuzzy = pd.read_csv('rep_candidates_fuzzy.csv')
rep_candidates_fuzzy.columns = ['rep_twitter_name', 'score', 'rep_name']
dem_candidates_fuzzy = pd.read_csv('dem_candidates_fuzzy.csv')
dem_candidates_fuzzy.columns = ['dem_twitter_name', 'score', 'dem_name']

# %%
election_results = pd.merge(election_results, rep_candidates_fuzzy, left_on='candidate_18_rep', right_on='rep_name')
election_results = pd.merge(election_results, dem_candidates_fuzzy, left_on='candidate_18_dem', right_on='dem_name')

# %%
state_candidate_twitter = election_results[['state', 'dem_twitter_name', 'rep_twitter_name']]
state_candidate_twitter = pd.melt(state_candidate_twitter, id_vars='state', value_vars=['dem_twitter_name', 'rep_twitter_name'] )

# %%
candidate_echo_vt = pd.merge(candidate_echo, state_candidate_twitter, left_on='Real Name', right_on='value')

# %% [markdown]
# now use voter turnout data

# %%
voter_turnout = pd.read_csv('voter_turnout.csv')[['State', 'Estimated or Actual 2018 Total Ballots Counted VEP Turnout Rate']]
voter_turnout.columns = ['state','voter_turnout']

# %%
voter_turnout['voter_turnout'] = voter_turnout.voter_turnout.apply(lambda x: float(x.strip('%')))

# %%
candidate_echo_vt = pd.merge(candidate_echo_vt, voter_turnout, left_on='state_x', right_on='state')

# %%
vt_analysis = candidate_echo_vt.groupby('state').agg({'voter_turnout': 'mean',
                                                      'n_candidate_followers': ['mean', 'min', 'max'],
                                                      'ratio_normalized': ['mean', 'min', 'max'],
                                                      'ratio_normalized_log':['mean', 'min', 'max'],
                                                      'ratio_normalized_state':['mean', 'min', 'max'],
                                                      'ratio': ['mean', 'min', 'max'],
                                                      'ratio_only_candidate': ['mean', 'min', 'max'],
                                                      'ratio_only_candidate_normalized': ['mean', 'min', 'max'],
                                                      'ratio_opponent_over_candidate_followers':['mean', 'min', 'max']})

# %%
vt_analysis.columns = ['%s%s' % (a, '_%s' % b if b else '') for a, b in vt_analysis.columns]

# %%
aggregation_ratios = {'voter_turnout': 'mean',
                      'n_candidate_followers': ['mean', 'min', 'max'],
                      'ratio_normalized': ['mean', 'min', 'max'],
                      'ratio_normalized_log':['mean', 'min', 'max'],
                      'ratio_normalized_state':['mean', 'min', 'max'],
                      'ratio': ['mean', 'min', 'max'],
                      'ratio_only_candidate': ['mean', 'min', 'max'],
                      'ratio_only_candidate_normalized': ['mean', 'min', 'max'],
                      'ratio_opponent_over_candidate_followers':['mean', 'min', 'max']}
ratios = list(aggregation_ratios.keys())
ratios
# Out:
# ['voter_turnout',
#  'n_candidate_followers',
#  'ratio_normalized',
#  'ratio_normalized_log',
#  'ratio_normalized_state',
#  'ratio',
#  'ratio_only_candidate',
#  'ratio_only_candidate_normalized',
#  'ratio_opponent_over_candidate_followers']

# %%
for ratio in ratios[1:]:
    vt_analysis[ratio + '_diff'] = vt_analysis[ratio + '_max'] - vt_analysis[ratio + '_min']

# %%
vt_analysis.head()
# Out:
#              voter_turnout_mean  n_candidate_followers_mean  \
# state
# California                 49.6                    711138.5
# Connecticut                54.4                    791927.0
# Delaware                   51.4                     96467.0
# Florida                    54.9                    347085.0
# Hawaii                     39.3                    414931.0
#
#              n_candidate_followers_min  n_candidate_followers_max  \
# state
# California                     55973.0                  1366304.0
# Connecticut                   791927.0                   791927.0
# Delaware                       96467.0                    96467.0
# Florida                       347085.0                   347085.0
# Hawaii                        414931.0                   414931.0
#
#              ratio_normalized_mean  ratio_normalized_min  \
# state
# California            8.879648e-07          1.027903e-07
# Connecticut           2.216335e-07          2.216335e-07
# Delaware              1.072510e-06          1.072510e-06
# Florida               3.047101e-07          3.047101e-07
# Hawaii                3.568869e-07          3.568869e-07
#
#              ratio_normalized_max  ratio_normalized_log_mean  \
# state
# California           1.673139e-06                   0.009254
# Connecticut          2.216335e-07                   0.012923
# Delaware             1.072510e-06                   0.009015
# Florida              3.047101e-07                   0.008290
# Hawaii               3.568869e-07                   0.011448
#
#              ratio_normalized_log_min  ratio_normalized_log_max  ...  \
# state                                                            ...
# California                   0.008566                  0.009941  ...
# Connecticut                  0.012923                  0.012923  ...
# Delaware                     0.009015                  0.009015  ...
# Florida                      0.008290                  0.008290  ...
# Hawaii                       0.011448                  0.011448  ...
#
#              ratio_opponent_over_candidate_followers_min  \
# state
# California                                      0.032124
# Connecticut                                     0.002351
# Delaware                                        0.000000
# Florida                                         0.000000
# Hawaii                                          0.000000
#
#              ratio_opponent_over_candidate_followers_max  \
# state
# California                                      0.131112
# Connecticut                                     0.002351
# Delaware                                        0.000000
# Florida                                         0.000000
# Hawaii                                          0.000000
#
#              n_candidate_followers_diff  ratio_normalized_diff  \
# state
# California                    1310331.0               0.000002
# Connecticut                         0.0               0.000000
# Delaware                            0.0               0.000000
# Florida                             0.0               0.000000
# Hawaii                              0.0               0.000000
#
#              ratio_normalized_log_diff  ratio_normalized_state_diff  \
# state
# California                    0.001375                 1.182904e-09
# Connecticut                   0.000000                 0.000000e+00
# Delaware                      0.000000                 0.000000e+00
# Florida                       0.000000                 0.000000e+00
# Hawaii                        0.000000                 0.000000e+00
#
#              ratio_diff  ratio_only_candidate_diff  \
# state
# California     0.046792                   0.076131
# Connecticut    0.000000                   0.000000
# Delaware       0.000000                   0.000000
# Florida        0.000000                   0.000000
# Hawaii         0.000000                   0.000000
#
#              ratio_only_candidate_normalized_diff  \
# state
# California                           9.008854e-07
# Connecticut                          0.000000e+00
# Delaware                             0.000000e+00
# Florida                              0.000000e+00
# Hawaii                               0.000000e+00
#
#              ratio_opponent_over_candidate_followers_diff
# state
# California                                       0.098988
# Connecticut                                      0.000000
# Delaware                                         0.000000
# Florida                                          0.000000
# Hawaii                                           0.000000
#
# [5 rows x 33 columns]

# %%
plt.scatter(vt_analysis.voter_turnout_mean,vt_analysis.ratio_normalized_mean*10000)
plt.title('Voter Turnout vs Mean Echo Chamber')
plt.show()
np.corrcoef(vt_analysis.voter_turnout_mean,vt_analysis.ratio_normalized_mean)
# Out:
# array([[1.        , 0.54077782],
#        [0.54077782, 1.        ]])

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(vt_analysis.iloc[:,1:])
X = pd.DataFrame(X, columns=vt_analysis.columns[1:], index = vt_analysis.index)
y = vt_analysis.voter_turnout_mean

# %%
import statsmodels.api as sm
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     voter_turnout_mean   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -1.578
# Method:                 Least Squares   F-statistic:                  0.005312
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):               1.00
# Time:                        16:41:32   Log-Likelihood:                -139.46
# No. Observations:                  26   AIC:                             310.9
# Df Residuals:                      10   BIC:                             331.0
# Df Model:                          16
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# n_candidate_followers_mean                      -2.0165     32.279     -0.062      0.951     -73.939      69.906
# n_candidate_followers_min                       -2.3793     64.864     -0.037      0.971    -146.905     142.147
# n_candidate_followers_max                       -1.4217     26.966     -0.053      0.959     -61.505      58.661
# ratio_normalized_mean                           -0.2472     34.956     -0.007      0.994     -78.134      77.639
# ratio_normalized_min                             1.1691     52.077      0.022      0.983    -114.865     117.203
# ratio_normalized_max                            -0.8656     58.571     -0.015      0.989    -131.369     129.638
# ratio_normalized_log_mean                       -3.0000    129.478     -0.023      0.982    -291.494     285.494
# ratio_normalized_log_min                         2.4011    122.544      0.020      0.985    -270.643     275.445
# ratio_normalized_log_max                        -9.2384    137.325     -0.067      0.948    -315.218     296.741
# ratio_normalized_state_mean                     -0.9110      7.340     -0.124      0.904     -17.266      15.444
# ratio_normalized_state_min                      -1.6869     17.489     -0.096      0.925     -40.655      37.281
# ratio_normalized_state_max                      -0.1072     16.558     -0.006      0.995     -37.002      36.787
# ratio_mean                                       8.3961    426.822      0.020      0.985    -942.623     959.415
# ratio_min                                       -1.6442    321.377     -0.005      0.996    -717.717     714.429
# ratio_max                                       18.4834    666.055      0.028      0.978   -1465.579    1502.546
# ratio_only_candidate_mean                       -4.3441    414.235     -0.010      0.992    -927.318     918.630
# ratio_only_candidate_min                         1.3711    278.840      0.005      0.996    -619.923     622.665
# ratio_only_candidate_max                       -10.5371    669.587     -0.016      0.988   -1502.470    1481.396
# ratio_only_candidate_normalized_mean             0.7279     76.592      0.010      0.993    -169.931     171.387
# ratio_only_candidate_normalized_min             -6.3090    111.778     -0.056      0.956    -255.367     242.749
# ratio_only_candidate_normalized_max              2.0592     76.100      0.027      0.979    -167.503     171.621
# ratio_opponent_over_candidate_followers_mean    -1.0714     54.782     -0.020      0.985    -123.134     120.991
# ratio_opponent_over_candidate_followers_min      3.4879    167.702      0.021      0.984    -370.176     377.152
# ratio_opponent_over_candidate_followers_max     -2.4498     43.077     -0.057      0.956     -98.431      93.532
# n_candidate_followers_diff                      -0.6003     34.151     -0.018      0.986     -76.693      75.493
# ratio_normalized_diff                           -1.5879     87.295     -0.018      0.986    -196.094     192.918
# ratio_normalized_log_diff                      -16.5538    122.116     -0.136      0.895    -288.645     255.537
# ratio_normalized_state_diff                     10.0254    192.320      0.052      0.959    -418.489     438.540
# ratio_diff                                      25.9032    839.924      0.031      0.976   -1845.564    1897.371
# ratio_only_candidate_diff                      -14.0572    736.021     -0.019      0.985   -1654.015    1625.900
# ratio_only_candidate_normalized_diff             3.5914     79.398      0.045      0.965    -173.318     180.501
# ratio_opponent_over_candidate_followers_diff    -4.2854     85.447     -0.050      0.961    -194.674     186.103
# ==============================================================================
# Omnibus:                        9.839   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                8.036
# Skew:                          -1.136   Prob(JB):                       0.0180
# Kurtosis:                       4.503   Cond. No.                     1.43e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 1.55e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
results.params.sort_values()
# Out:
# ratio_normalized_log_diff                      -16.553788
# ratio_only_candidate_diff                      -14.057178
# ratio_only_candidate_max                       -10.537089
# ratio_normalized_log_max                        -9.238438
# ratio_only_candidate_normalized_min             -6.309048
# ratio_only_candidate_mean                       -4.344076
# ratio_opponent_over_candidate_followers_diff    -4.285433
# ratio_normalized_log_mean                       -3.000001
# ratio_opponent_over_candidate_followers_max     -2.449784
# n_candidate_followers_min                       -2.379297
# n_candidate_followers_mean                      -2.016499
# ratio_normalized_state_min                      -1.686882
# ratio_min                                       -1.644162
# ratio_normalized_diff                           -1.587936
# n_candidate_followers_max                       -1.421737
# ratio_opponent_over_candidate_followers_mean    -1.071392
# ratio_normalized_state_mean                     -0.910964
# ratio_normalized_max                            -0.865552
# n_candidate_followers_diff                      -0.600264
# ratio_normalized_mean                           -0.247157
# ratio_normalized_state_max                      -0.107159
# ratio_only_candidate_normalized_mean             0.727862
# ratio_normalized_min                             1.169089
# ratio_only_candidate_min                         1.371113
# ratio_only_candidate_normalized_max              2.059232
# ratio_normalized_log_min                         2.401053
# ratio_opponent_over_candidate_followers_min      3.487944
# ratio_only_candidate_normalized_diff             3.591391
# ratio_mean                                       8.396115
# ratio_normalized_state_diff                     10.025403
# ratio_max                                       18.483386
# ratio_diff                                      25.903247
# dtype: float64

# %% [markdown]
# # ELECTION OUTCOME

# %%
election_results['dem_winner18'] = (election_results.pct_votes_18_dem > election_results.pct_votes_18_rep)*1

# %%
election_results = pd.merge(election_results, vt_analysis, 
                            left_on='state', right_index=True, 
                            how='right')

# %%
er_model = election_results[list(election_results.corr().columns)]
columns_drop = ['Unnamed: 0', 'pct_votes_18_rep', 'score_x', 'score_y', 'voter_turnout_mean', 'state_senate_other_seats17']
er_model.drop(columns=columns_drop, inplace=True)
er_model.set_index(vt_analysis.index, inplace=True)
# Out:
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
y1 = er_model.pct_votes_18_dem
y2 = er_model.dem_winner18
er_model.drop(columns=['pct_votes_18_dem', 'dem_winner18'], inplace=True)
# Out:
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
X = StandardScaler().fit_transform(er_model)
X = pd.DataFrame(X, columns=er_model.columns, index=er_model.index)
# Out:
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
import statsmodels.api as sm
model = sm.OLS(y1, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       pct_votes_18_dem   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                -23.628
# Method:                 Least Squares   F-statistic:                  0.002229
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):               1.00
# Time:                        16:53:05   Log-Likelihood:                -19.458
# No. Observations:                  26   AIC:                             88.92
# Df Residuals:                       1   BIC:                             120.4
# Df Model:                          25
# Covariance Type:            nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# candidatevotes_win12                             0.0035      0.178      0.020      0.987      -2.258       2.265
# totalvotes_win12                                 0.0029      0.207      0.014      0.991      -2.631       2.637
# pct_votes_win12                                  0.0028      0.520      0.005      0.997      -6.606       6.611
# n_candidates_win12                              -0.0022      0.500     -0.004      0.997      -6.350       6.346
# gpoll_conservative_18                           -0.0087      0.349     -0.025      0.984      -4.440       4.423
# gpoll_moderate_18                                0.0192      0.460      0.042      0.973      -5.831       5.869
# gpoll_liberal_18                                -0.0055      0.290     -0.019      0.988      -3.693       3.682
# gpoll_conservative_advantage_18                 -0.0024      0.295     -0.008      0.995      -3.749       3.744
# gpoll_trump_approval_17                         -0.0016      0.302     -0.005      0.997      -3.840       3.837
# gpoll_trump_disapproval_17                      -0.0004      0.305     -0.001      0.999      -3.871       3.870
# gpoll_republican_lean_17                        -0.0030      0.142     -0.021      0.986      -1.810       1.804
# gpoll_democratic_lean_17                         0.0050      0.247      0.020      0.987      -3.136       3.146
# gpoll_democratic_advantage_17                    0.0046      0.183      0.025      0.984      -2.317       2.326
# gpoll_conservative_17                           -0.0030      0.192     -0.016      0.990      -2.438       2.432
# gpoll_moderate_17                                0.0227      0.500      0.045      0.971      -6.332       6.377
# gpoll_liberal_17                                -0.0056      0.276     -0.020      0.987      -3.516       3.505
# gpoll_conservative_advantage_17                  0.0010      0.211      0.005      0.997      -2.674       2.676
# gpoll_economic_confidence_index_17              -0.0084      0.418     -0.020      0.987      -5.318       5.302
# gpoll_very_religious_17                          0.0054      0.361      0.015      0.991      -4.585       4.595
# gpoll_moderately_religious_17                    0.0266      0.470      0.057      0.964      -5.942       5.995
# gpoll_nonreligious_17                           -0.0170      0.401     -0.042      0.973      -5.114       5.080
# gpoll_overall_well_being_17                     -0.0079      0.300     -0.026      0.983      -3.821       3.805
# gpoll_uninsured_rate_17                         -0.0141      0.407     -0.035      0.978      -5.189       5.161
# gpoll_exercise_frequently_17                     0.0087      0.504      0.017      0.989      -6.400       6.417
# gpoll_eat_produce_frequently_17                  0.0011      0.566      0.002      0.999      -7.192       7.194
# gpoll_community_recognition_17                  -0.0087      0.346     -0.025      0.984      -4.402       4.384
# gpoll_feel_active_and_productive_17             -0.0064      0.617     -0.010      0.993      -7.840       7.827
# gpoll_worried_about_money_17                    -0.0111      0.506     -0.022      0.986      -6.444       6.422
# gpoll_trump_approval_18                          0.0037      0.186      0.020      0.987      -2.356       2.364
# gpoll_trump_disapproval_18                      -0.0049      0.384     -0.013      0.992      -4.889       4.879
# state_senate_dem_seats17                         0.0012      0.515      0.002      0.999      -6.546       6.548
# state_senate_rep_seats17                        -0.0037      0.535     -0.007      0.996      -6.797       6.789
# state_house_dem_seats17                         -0.0054      0.419     -0.013      0.992      -5.326       5.315
# state_house_rep_seats17                         -0.0074      0.393     -0.019      0.988      -5.001       4.986
# state_senate_diff17                              0.0028      0.415      0.007      0.996      -5.275       5.281
# state_house_diff17                               0.0013      0.352      0.004      0.998      -4.471       4.474
# pew_income_change_07                             0.0184      0.647      0.028      0.982      -8.205       8.242
# pew_income_change_08                             0.0039      0.566      0.007      0.996      -7.190       7.198
# pew_income_change_09                             0.0039      0.461      0.009      0.995      -5.857       5.865
# pew_income_change_10                            -0.0048      0.616     -0.008      0.995      -7.837       7.828
# pew_income_change_11                             0.0078      0.479      0.016      0.990      -6.084       6.100
# pew_income_change_12                             0.0093      0.541      0.017      0.989      -6.863       6.882
# pew_income_change_13                            -0.0013      0.588     -0.002      0.999      -7.477       7.474
# pew_income_change_14                            -0.0006      0.428     -0.001      0.999      -5.444       5.443
# pew_income_change_15                             0.0054      0.498      0.011      0.993      -6.326       6.336
# pew_income_change_16                            -0.0013      0.456     -0.003      0.998      -5.792       5.789
# pew_income_change_17                            -0.0072      0.513     -0.014      0.991      -6.520       6.505
# pew_income_change_18                            -0.0018      0.537     -0.003      0.998      -6.826       6.823
# candidatevotes2012_dem                           0.0045      0.268      0.017      0.989      -3.399       3.408
# candidatevotes2016_dem                           0.0019      0.222      0.008      0.995      -2.817       2.821
# totalvotes2012_dem                               0.0030      0.210      0.014      0.991      -2.663       2.669
# totalvotes2016_dem                               0.0011      0.181      0.006      0.996      -2.300       2.302
# pct_votes2012_dem                                0.0058      0.311      0.019      0.988      -3.940       3.951
# pct_votes2016_dem                                0.0074      0.230      0.032      0.979      -2.915       2.930
# candidate_votes_18_dem                           0.0046      0.109      0.042      0.973      -1.382       1.391
# candidate_votes_18_rep                          -0.0004      0.288     -0.001      0.999      -3.656       3.655
# incumbent_dem                                    0.0093      0.425      0.022      0.986      -5.395       5.414
# incumbent_rep                                   -0.0076      0.349     -0.022      0.986      -4.447       4.432
# incumbent                                        0.0047      0.457      0.010      0.993      -5.807       5.817
# n_candidate_followers_mean                     2.94e-05      0.267      0.000      1.000      -3.395       3.395
# n_candidate_followers_min                       -0.0064      0.356     -0.018      0.989      -4.536       4.523
# n_candidate_followers_max                        0.0022      0.268      0.008      0.995      -3.401       3.405
# ratio_normalized_mean                            0.0011      0.312      0.003      0.998      -3.961       3.963
# ratio_normalized_min                            -0.0048      0.519     -0.009      0.994      -6.597       6.587
# ratio_normalized_max                             0.0036      0.329      0.011      0.993      -4.178       4.186
# ratio_normalized_log_mean                        0.0075      0.201      0.037      0.976      -2.549       2.564
# ratio_normalized_log_min                         0.0070      0.259      0.027      0.983      -3.281       3.295
# ratio_normalized_log_max                         0.0072      0.210      0.034      0.978      -2.656       2.671
# ratio_normalized_state_mean                     -0.0061      0.283     -0.022      0.986      -3.598       3.586
# ratio_normalized_state_min                      -0.0065      0.282     -0.023      0.985      -3.595       3.582
# ratio_normalized_state_max                      -0.0057      0.283     -0.020      0.987      -3.596       3.585
# ratio_mean                                       0.0042      0.093      0.045      0.971      -1.177       1.185
# ratio_min                                        0.0041      0.106      0.039      0.975      -1.343       1.352
# ratio_max                                        0.0037      0.116      0.031      0.980      -1.470       1.478
# ratio_only_candidate_mean                        0.0042      0.106      0.039      0.975      -1.347       1.355
# ratio_only_candidate_min                         0.0048      0.137      0.035      0.978      -1.736       1.746
# ratio_only_candidate_max                         0.0027      0.122      0.022      0.986      -1.551       1.556
# ratio_only_candidate_normalized_mean             0.0023      0.254      0.009      0.994      -3.219       3.224
# ratio_only_candidate_normalized_min              0.0213      0.478      0.044      0.972      -6.052       6.095
# ratio_only_candidate_normalized_max             -0.0016      0.323     -0.005      0.997      -4.107       4.104
# ratio_opponent_over_candidate_followers_mean    -0.0084      0.282     -0.030      0.981      -3.589       3.572
# ratio_opponent_over_candidate_followers_min      0.0009      0.373      0.002      0.998      -4.742       4.744
# ratio_opponent_over_candidate_followers_max     -0.0106      0.310     -0.034      0.978      -3.949       3.928
# n_candidate_followers_diff                       0.0044      0.292      0.015      0.990      -3.706       3.715
# ratio_normalized_diff                            0.0066      0.470      0.014      0.991      -5.961       5.975
# ratio_normalized_log_diff                       -0.0019      0.446     -0.004      0.997      -5.669       5.665
# ratio_normalized_state_diff                      0.0064      0.250      0.025      0.984      -3.169       3.181
# ratio_diff                                      -0.0012      0.187     -0.007      0.996      -2.379       2.377
# ratio_only_candidate_diff                       -0.0036      0.224     -0.016      0.990      -2.848       2.841
# ratio_only_candidate_normalized_diff            -0.0064      0.417     -0.015      0.990      -5.304       5.292
# ratio_opponent_over_candidate_followers_diff    -0.0130      0.381     -0.034      0.978      -4.855       4.829
# ==============================================================================
# Omnibus:                        2.795   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.247   Jarque-Bera (JB):                2.273
# Skew:                          -0.710   Prob(JB):                        0.321
# Kurtosis:                       2.716   Cond. No.                     1.25e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# [3] The smallest eigenvalue is 4.1e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import statsmodels.api as sm
model = sm.Logit(y2, X)
results = model.fit_regularized()
print(results.summary())
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4286571082016174e-10
#             Iterations: 38
#             Function evaluations: 38
#             Gradient evaluations: 38
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           dem_winner18   No. Observations:                   26
# Model:                          Logit   Df Residuals:                      -65
# Method:                           MLE   Df Model:                           90
# Date:                Fri, 15 Nov 2019   Pseudo R-squ.:                   1.000
# Time:                        16:52:46   Log-Likelihood:            -3.7145e-09
# converged:                       True   LL-Null:                       -16.048
#                                         LLR p-value:                     1.000
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# candidatevotes_win12                             1.5232        nan        nan        nan         nan         nan
# totalvotes_win12                                 1.4321        nan        nan        nan         nan         nan
# pct_votes_win12                                 -4.5483        nan        nan        nan         nan         nan
# n_candidates_win12                              -5.7136        nan        nan        nan         nan         nan
# gpoll_conservative_18                           -4.0212        nan        nan        nan         nan         nan
# gpoll_moderate_18                                2.9501        nan        nan        nan         nan         nan
# gpoll_liberal_18                                -0.5178   8.32e+11  -6.22e-13      1.000   -1.63e+12    1.63e+12
# gpoll_conservative_advantage_18                 -2.0608    4.7e+11  -4.39e-12      1.000    -9.2e+11     9.2e+11
# gpoll_trump_approval_17                          2.6711   1.79e+12   1.49e-12      1.000    -3.5e+12     3.5e+12
# gpoll_trump_disapproval_17                      -1.2788        nan        nan        nan         nan         nan
# gpoll_republican_lean_17                        -2.5338   2.58e+12  -9.81e-13      1.000   -5.06e+12    5.06e+12
# gpoll_democratic_lean_17                         6.1420        nan        nan        nan         nan         nan
# gpoll_democratic_advantage_17                    4.8184        nan        nan        nan         nan         nan
# gpoll_conservative_17                           -2.0421        nan        nan        nan         nan         nan
# gpoll_moderate_17                                8.0702   9.78e+11   8.26e-12      1.000   -1.92e+12    1.92e+12
# gpoll_liberal_17                                -0.1455        nan        nan        nan         nan         nan
# gpoll_conservative_advantage_17                 -1.1192        nan        nan        nan         nan         nan
# gpoll_economic_confidence_index_17              -6.6700        nan        nan        nan         nan         nan
# gpoll_very_religious_17                         -4.5033        nan        nan        nan         nan         nan
# gpoll_moderately_religious_17                    7.1022   4.73e+11    1.5e-11      1.000   -9.27e+11    9.27e+11
# gpoll_nonreligious_17                           -1.5691   1.02e+12  -1.54e-12      1.000      -2e+12       2e+12
# gpoll_overall_well_being_17                     -6.8882        nan        nan        nan         nan         nan
# gpoll_uninsured_rate_17                         -9.3467   2.15e+11  -4.35e-11      1.000   -4.21e+11    4.21e+11
# gpoll_exercise_frequently_17                     1.3543        nan        nan        nan         nan         nan
# gpoll_eat_produce_frequently_17                  3.4674   1.05e+12   3.29e-12      1.000   -2.06e+12    2.06e+12
# gpoll_community_recognition_17                   0.6896        nan        nan        nan         nan         nan
# gpoll_feel_active_and_productive_17             -6.0656   1.81e+11  -3.35e-11      1.000   -3.55e+11    3.55e+11
# gpoll_worried_about_money_17                     1.4435        nan        nan        nan         nan         nan
# gpoll_trump_approval_18                          2.6337        nan        nan        nan         nan         nan
# gpoll_trump_disapproval_18                      -1.2004   7.89e+11  -1.52e-12      1.000   -1.55e+12    1.55e+12
# state_senate_dem_seats17                         5.1947        nan        nan        nan         nan         nan
# state_senate_rep_seats17                         2.5770        nan        nan        nan         nan         nan
# state_house_dem_seats17                         -2.7130        nan        nan        nan         nan         nan
# state_house_rep_seats17                         -5.6334   6.72e+11  -8.38e-12      1.000   -1.32e+12    1.32e+12
# state_senate_diff17                              1.9234   2.42e+11   7.94e-12      1.000   -4.75e+11    4.75e+11
# state_house_diff17                               2.7862        nan        nan        nan         nan         nan
# pew_income_change_07                             2.2099   5.27e+11   4.19e-12      1.000   -1.03e+12    1.03e+12
# pew_income_change_08                            -1.5927   3.46e+11  -4.61e-12      1.000   -6.78e+11    6.78e+11
# pew_income_change_09                            -0.2993   1.77e+11  -1.69e-12      1.000   -3.46e+11    3.46e+11
# pew_income_change_10                            -2.5910        nan        nan        nan         nan         nan
# pew_income_change_11                             0.9669        nan        nan        nan         nan         nan
# pew_income_change_12                             1.7409        nan        nan        nan         nan         nan
# pew_income_change_13                            -5.4698        nan        nan        nan         nan         nan
# pew_income_change_14                            -3.6962   5.35e+11  -6.91e-12      1.000   -1.05e+12    1.05e+12
# pew_income_change_15                             1.1452    4.5e+11   2.54e-12      1.000   -8.82e+11    8.82e+11
# pew_income_change_16                            -2.4508   2.17e+11  -1.13e-11      1.000   -4.26e+11    4.26e+11
# pew_income_change_17                            -1.8556   9.19e+11  -2.02e-12      1.000    -1.8e+12     1.8e+12
# pew_income_change_18                             2.0337        nan        nan        nan         nan         nan
# candidatevotes2012_dem                           1.4293   1.52e+11   9.41e-12      1.000   -2.98e+11    2.98e+11
# candidatevotes2016_dem                           0.9048        nan        nan        nan         nan         nan
# totalvotes2012_dem                               1.3510   3.98e+11   3.39e-12      1.000    -7.8e+11     7.8e+11
# totalvotes2016_dem                               0.9157        nan        nan        nan         nan         nan
# pct_votes2012_dem                                3.4756   7.61e+11   4.57e-12      1.000   -1.49e+12    1.49e+12
# pct_votes2016_dem                                2.4393   1.34e+12   1.82e-12      1.000   -2.63e+12    2.63e+12
# candidate_votes_18_dem                           1.7341   4.44e+11    3.9e-12      1.000   -8.71e+11    8.71e+11
# candidate_votes_18_rep                          -1.7131   1.47e+11  -1.16e-11      1.000   -2.88e+11    2.88e+11
# incumbent_dem                                    7.1987    3.3e+11   2.18e-11      1.000   -6.47e+11    6.47e+11
# incumbent_rep                                   -4.9434   1.22e+12  -4.07e-12      1.000   -2.38e+12    2.38e+12
# incumbent                                        3.9362   7.38e+11   5.33e-12      1.000   -1.45e+12    1.45e+12
# n_candidate_followers_mean                      -2.3888   1.06e+12  -2.26e-12      1.000   -2.07e+12    2.07e+12
# n_candidate_followers_min                       -3.4986        nan        nan        nan         nan         nan
# n_candidate_followers_max                       -1.0347        nan        nan        nan         nan         nan
# ratio_normalized_mean                            4.6468        nan        nan        nan         nan         nan
# ratio_normalized_min                             1.5721        nan        nan        nan         nan         nan
# ratio_normalized_max                             5.2158   5.21e+11      1e-11      1.000   -1.02e+12    1.02e+12
# ratio_normalized_log_mean                        3.1392        nan        nan        nan         nan         nan
# ratio_normalized_log_min                         4.6904        nan        nan        nan         nan         nan
# ratio_normalized_log_max                         0.1878   1.13e+12   1.66e-13      1.000   -2.22e+12    2.22e+12
# ratio_normalized_state_mean                     -2.8238        nan        nan        nan         nan         nan
# ratio_normalized_state_min                      -2.9167   1.67e+11  -1.74e-11      1.000   -3.28e+11    3.28e+11
# ratio_normalized_state_max                      -2.7105        nan        nan        nan         nan         nan
# ratio_mean                                       0.4266   1.09e+12   3.92e-13      1.000   -2.13e+12    2.13e+12
# ratio_min                                        2.4132        nan        nan        nan         nan         nan
# ratio_max                                       -1.8593        nan        nan        nan         nan         nan
# ratio_only_candidate_mean                        0.3184   5.03e+11   6.33e-13      1.000   -9.86e+11    9.86e+11
# ratio_only_candidate_min                         2.3876        nan        nan        nan         nan         nan
# ratio_only_candidate_max                        -2.0724   4.21e+11  -4.93e-12      1.000   -8.24e+11    8.24e+11
# ratio_only_candidate_normalized_mean             4.4625   1.21e+12    3.7e-12      1.000   -2.36e+12    2.36e+12
# ratio_only_candidate_normalized_min              8.3791        nan        nan        nan         nan         nan
# ratio_only_candidate_normalized_max              2.7385   1.28e+12   2.14e-12      1.000   -2.51e+12    2.51e+12
# ratio_opponent_over_candidate_followers_mean    -1.8508   6.32e+11  -2.93e-12      1.000   -1.24e+12    1.24e+12
# ratio_opponent_over_candidate_followers_min     -1.4888   3.34e+11  -4.46e-12      1.000   -6.54e+11    6.54e+11
# ratio_opponent_over_candidate_followers_max     -1.8688        nan        nan        nan         nan         nan
# n_candidate_followers_diff                       0.6912   1.19e+12   5.79e-13      1.000   -2.34e+12    2.34e+12
# ratio_normalized_diff                            5.0177        nan        nan        nan         nan         nan
# ratio_normalized_log_diff                       -6.5269        nan        nan        nan         nan         nan
# ratio_normalized_state_diff                      1.2689   5.35e+11   2.37e-12      1.000   -1.05e+12    1.05e+12
# ratio_diff                                      -3.5479   4.94e+11  -7.18e-12      1.000   -9.68e+11    9.68e+11
# ratio_only_candidate_diff                       -3.4636   7.85e+11  -4.41e-12      1.000   -1.54e+12    1.54e+12
# ratio_only_candidate_normalized_diff             0.5095   1.75e+12   2.91e-13      1.000   -3.43e+12    3.43e+12
# ratio_opponent_over_candidate_followers_diff    -1.7510   6.82e+11  -2.57e-12      1.000   -1.34e+12    1.34e+12
# ================================================================================================================
#
# Complete Separation: The results show that there iscomplete separation.
# In this case the Maximum Likelihood Estimator does not exist and the parameters
# are not identified.
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:1092: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/davidreissmello/anaconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
